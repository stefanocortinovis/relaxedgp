# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import logging
import sys

import matplotlib.pyplot as plt
import numpy as np
from gpflow.models.util import inducingpoint_wrapper

from relaxedgp.schedules import ConstantSchedule
from relaxedgp_experiments.base import Experiment
# Out:
# /Users/scortino/.local/share/mamba/envs/relaxedgp-env/lib/python3.12/site-packages/gpflow/versions.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
logger = logging.getLogger(__name__)
logging.basicConfig(stream=sys.stdout, level=logging.WARNING)
logging.getLogger("matplotlib").setLevel(logging.WARNING)

# %% [markdown]
# ## W-SVGP

# %%
experiment_config = {
    "log_dir": "./",  # log figures, if any
    "dataset_name": "snelson",
    "model_name": "wsvgp",
    "task": "regression",
    "kernel_name": "squared_exponential",
    "train_only": True,
    "origin": "local",
    "normalize_data": False,
    "M": 10,
    "init_Z_method": "random",
    "preconditioner": "identity",
}

# %%
run_config = {
    "n_iter": 10000,
    "adam_lr": 5e-3,
    "natgrad_schedule": ConstantSchedule(max_steps=1, value=1.0),
    "train_Z": False,
    "batch_size": 10,
    "evaluate_every": 1000,
    "debug_full_loss": True,
    "verbose": False,
}

# %%
experiment = Experiment(
    **experiment_config,
    logger=logger,
)

# %%
X_train = experiment.train_data[0]
left = X_train.min()
right = X_train.max()
grid = np.linspace(left, right, experiment_config["M"])[:, np.newaxis]
experiment.model.inducing_variable = inducingpoint_wrapper(grid.copy())

# %%
lmls_wsvgp = experiment.run(
    **run_config,
)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1775031616.975892 4979857 service.cc:145] XLA service 0x60000230ae00 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1775031616.975909 4979857 service.cc:153]   StreamExecutor device (0): Host, Default Version
# 2026-04-01 10:20:16.996279: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1775031617.195035 4979857 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.

# %% [markdown]
# ## L-SVGP

# %%
experiment_config["model_name"] = "lsvgp"

# %%
experiment = Experiment(
    **experiment_config,
    logger=logger,
)

# %%
experiment.model.inducing_variable = inducingpoint_wrapper(grid.copy())

# %%
lmls_lsvgp = experiment.run(
    **run_config,
)

# %% [markdown]
# ## L-SVGP (P)

# %%
experiment_config["preconditioner"] = "inv"

# %%
experiment = Experiment(
    **experiment_config,
    logger=logger,
)

# %%
experiment.model.inducing_variable = inducingpoint_wrapper(grid.copy())

# %%
lmls_lsvgp_p = experiment.run(
    **run_config,
)

# %% [markdown]
# ## R-SVGP (N)

# %%
experiment_config["model_name"] = "rsvgp_n"
experiment_config["preconditioner"] = "identity"

# %%
experiment = Experiment(
    **experiment_config,
    logger=logger,
)

# %%
experiment.model.inducing_variable = inducingpoint_wrapper(grid.copy())

# %%
lmls_rsvgp_n = experiment.run(
    **run_config,
);

# %% [markdown]
# ## R-SVGP (NP)

# %%
experiment_config["model_name"] = "rsvgp_n"
experiment_config["preconditioner"] = "T"

# %%
experiment = Experiment(
    **experiment_config,
    logger=logger,
)

# %%
experiment.model.inducing_variable = inducingpoint_wrapper(grid.copy())

# %%
lmls_rsvgp_np = experiment.run(
    **run_config,
)

# %% [markdown]
# ## R-SVGP

# %%
experiment_config["model_name"] = "rsvgp"
experiment_config["preconditioner"] = "identity"

# %%
experiment = Experiment(
    **experiment_config,
    logger=logger,
)

# %%
experiment.model.inducing_variable = inducingpoint_wrapper(grid.copy())

# %%
lmls_rsvgp = experiment.run(
    **run_config,
)

# %% [markdown]
# ## R-SVGP (P)

# %%
experiment_config["preconditioner"] = "T"

# %%
experiment = Experiment(
    **experiment_config,
    logger=logger,
)

# %%
experiment.model.inducing_variable = inducingpoint_wrapper(grid.copy())

# %%
lmls_rsvgp_p = experiment.run(
    **run_config,
)

# %% [markdown]
# ## Trace plot

# %%
lmls = [
    lmls_wsvgp,
    lmls_lsvgp,
    lmls_lsvgp_p,
    lmls_rsvgp,
    lmls_rsvgp_p,
    lmls_rsvgp_n,
    lmls_rsvgp_np,
]
methods = [
    "W-SVGP",
    "L-SVGP",
    "L-SVGP (P)",
    "R-SVGP",
    "R-SVGP (P)",
    "R-SVGP (N)",
    "R-SVGP (NP)",
]

# %%
fig, ax = plt.subplots(1, 1, figsize=(3.74, 3))

for i, (lml, label) in enumerate(zip(lmls, methods)):
    lml = np.vstack(lml)
    ax.plot(lml[:, 0], lml[:, 2], label=label, color=f"C{i}")

ax.set_title("\\textsc{snelson} $(M = 10)$")
ax.set_xlabel("iteration")
ax.set_ylabel("negative ELBO")
ax.set_ylim(55, 100)

h, l = ax.get_legend_handles_labels()
fig.legend(h, l, loc="center", bbox_to_anchor=(0.5, 0), ncol=7, fontsize=8)
plt.tight_layout()
plt.subplots_adjust(bottom=0.2)
